# %% [markdown]
# # Lecture 1.2.1
#
# New accepted definition of opterations management
#
# - the design, operation and improvement of the systems that create and deliver the firms primary value. it is valid for all value propositions (goods and services)

# %% [markdown]
# # Lecture 1.2.2 | Areas of Operations
#
# ## Operations Management: Discipline
#
# - operations management has several broad areas of interest
#
# - process analysis and design
#
# - supply chain management
#
# - process improvement and quality
#     - we will cover each with theoretical lectures, exercises, and lectures
#
# - an area that we will not cover at all relates to project management

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lecture 1.2.3 | Mass Customization of M&M's (candy)
#
# # Lecture 1.3.1 | Operations is All About Trade-offs
#
# Choosing the right combination of these four factors
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - OM helps provide tools to support **strategic trade-offs**
#
# - OM helps provide tools to identify and eliminate **inefficiencies**
#
# - OM helps evaluate **system designs** before they occur

# %% [markdown]
# # Lecture 1.3.3 | Pareto Principle

# %% [markdown]
# ## Pareto Phenomenon
#
# - a few factors account for a high percentage of the occurrence of some event(s)
#
# - 80/20 rule
#     - 80\% of problems are cuased by 20\% of the activities
#     - 80\% of revenue comes from 20\% of customers (generated by 20\% of workers)
#
# how do we identify the vital few?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lecture 1.4.3 | Perspectives on Operations Strategy

# %% [markdown]
# - operations strategy is the the total pattern of decisions...
#
# - that shape the long-term apabilities of any type of operation...
#
# - and their contribution to overall strategy...
#
# - through the on-going reconciliation of market requieremnts and oeprations resources...
#
# - so as to acheieve a sustainable fit between the two...
#
# - whilst managing the risks of misalignment...

# %% [markdown]
# ## Operations Management vs Operations Strategy
#
# - management
#     - micro
#     - short-term
#     - detailed
#     - concrete
#
# - strategy
#     - long-term
#     - macro
#     - aggregated
#     - more philosophical

# %% [markdown]
# ## The Four Perspectives on Operations Strategy
#
# - top-down
#     - should interpret higher-level strategy
#
# - bottom-up
#     - should learn from day to day experiences
#
# - market requirements
#     - should satisfy the organizations markets
#
# - operations resources
#     - should build operations capabilities
#     - will dictate what we actually do because of what is available

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Strategy: UPS vs FedEx
#
# - UPS = cost driven strategy
#     - DO NOT MAKE LEFT TURNS
#
# - FedEx = revenue focused
#     - will delivery nextday only if you deliver it
#     - if someone did not pay for next day delivery, but the package can be delivered next day - they will send a truck at a later time inefficient in terms of logistics but is revenue focused.

# %% [markdown]
# - stragey gap
# - capability gap
# - process gap
#
# ![image.png](attachment:image.png)
#
# P = price
#
# T = time
#
# Q = quality
#
# V = variability
