# %% [markdown]
# # Lecture 2.1.1 | What is a (Good) Process?

# %% [markdown]
# "if you cannot describe what you are doing as a process, you do not know what you are doing" - W.E. Deming

# %% [markdown]
# ## What is a Process?
#
# * a process is a series of independent tasks that transforms an input into output material of higher value for the organization and its stake holders
#
# * examples
#     - toyota: transforms steel, rubber, and plastic into cars
#     - mcdonalds: transforms mean, potatoes, and sauces into a happy mean
#     - an mba program transforms?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2.1.2 | the google process

# %% [markdown]
# # 2.1.3 | Process Analysis Flow Chart
#
# * lets look at the process "black box" in more details
#
# * why do we need to analyze the process?
#     - to identify inefficient tasks
#     - to spot possible effectiveness improvement tasks
#     - to understand where value can be added
#     - first order of busienss: map the process

# %% [markdown]
# ![image.png](attachment:image.png)
